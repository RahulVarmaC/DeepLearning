# %%
#conda install opencv
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\crahu\anaconda3\envs\CRV
#
#   added / updated specs:
#     - opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     freeglut-3.2.2             |       h0e60522_1         150 KB  conda-forge
#     intel-openmp-2022.0.0      |    h57928b3_3663         3.6 MB  conda-forge
#     jpeg-9e                    |       h8ffe710_0         373 KB  conda-forge
#     libblas-3.9.0              |     13_win64_mkl         5.3 MB  conda-forge
#     libcblas-3.9.0             |     13_win64_mkl         5.3 MB  conda-forge
#     libdeflate-1.10            |       h8ffe710_0          69 KB  conda-forge
#     liblapack-3.9.0            |     13_win64_mkl         5.3 MB  conda-forge
#     liblapacke-3.9.0           |     13_win64_mkl         5.3 MB  conda-forge
#     libopencv-4.5.5            |   py37h04cf790_3        47.5 MB  conda-forge
#     libtiff-4.3.0              |       hc4061b1_3         1.1 MB  conda-forge
#     mkl-2022.0.0               |     h0e2418a_796       181.9 MB  conda-forge
#     numpy-1.21.5               |   py37h5fa1a60_0         5.6 MB  conda-forge
#     opencv-4.5.5               |   py37h03978a9_3          23 KB  conda-forge
#     py-opencv-4.5.5            |   py37h4038f58_3          25 KB  conda-forge
#     tbb-2021.5.0               |       h2d74725_0         148 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       261.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   freeglut           conda-forge/win-64::freeglut-3.2.2-h0e60522_1
#   freetype           conda-forge/win-64::freetype-2.10.4-h546665d_1
#   icu                conda-forge/win-64::icu-68.2-h0e60522_0
#   intel-openmp       conda-forge/win-64::intel-openmp-2022.0.0-h57928b3_3663
#   jasper             conda-forge/win-64::jasper-2.0.33-h77af90b_0
#   jbig               conda-forge/win-64::jbig-2.1-h8d14728_2003
#   jpeg               conda-forge/win-64::jpeg-9e-h8ffe710_0
#   lerc               conda-forge/win-64::lerc-3.0-h0e60522_0
#   libblas            conda-forge/win-64::libblas-3.9.0-13_win64_mkl
#   libcblas           conda-forge/win-64::libcblas-3.9.0-13_win64_mkl
#   libclang           conda-forge/win-64::libclang-11.1.0-default_h5c34c98_1
#   libdeflate         conda-forge/win-64::libdeflate-1.10-h8ffe710_0
#   liblapack          conda-forge/win-64::liblapack-3.9.0-13_win64_mkl
#   liblapacke         conda-forge/win-64::liblapacke-3.9.0-13_win64_mkl
#   libopencv          conda-forge/win-64::libopencv-4.5.5-py37h04cf790_3
#   libpng             conda-forge/win-64::libpng-1.6.37-h1d00b33_2
#   libprotobuf        conda-forge/win-64::libprotobuf-3.19.4-h7755175_0
#   libtiff            conda-forge/win-64::libtiff-4.3.0-hc4061b1_3
#   libwebp-base       conda-forge/win-64::libwebp-base-1.2.2-h8ffe710_1
#   libzlib            conda-forge/win-64::libzlib-1.2.11-h8ffe710_1013
#   lz4-c              conda-forge/win-64::lz4-c-1.9.3-h8ffe710_1
#   mkl                conda-forge/win-64::mkl-2022.0.0-h0e2418a_796
#   numpy              conda-forge/win-64::numpy-1.21.5-py37h5fa1a60_0
#   opencv             conda-forge/win-64::opencv-4.5.5-py37h03978a9_3
#   py-opencv          conda-forge/win-64::py-opencv-4.5.5-py37h4038f58_3
#   qt                 conda-forge/win-64::qt-5.12.9-h5909a2a_4
#   tbb                conda-forge/win-64::tbb-2021.5.0-h2d74725_0
#   xz                 conda-forge/win-64::xz-5.2.5-h62dcd97_1
#   zlib               conda-forge/win-64::zlib-1.2.11-h8ffe710_1013
#   zstd               conda-forge/win-64::zstd-1.5.2-h6255e5f_0
#
# The following packages will be DOWNGRADED:
#
#   openssl                                  3.0.0-h8ffe710_2 --> 1.1.1l-h8ffe710_0
#   python                        3.7.12-h900ac77_100_cpython --> 3.7.12-h7840368_100_cpython
#
#
#
# Downloading and Extracting Packages
#
# jpeg-9e              | 373 KB    |            |   0%
# jpeg-9e              | 373 KB    | 4          |   4%
# jpeg-9e              | 373 KB    | ########## | 100%
#
# libblas-3.9.0        | 5.3 MB    |            |   0%
# libblas-3.9.0        | 5.3 MB    | 8          |   9%
# libblas-3.9.0        | 5.3 MB    | ######6    |  66%
# libblas-3.9.0        | 5.3 MB    | ########## | 100%
#
# liblapack-3.9.0      | 5.3 MB    |            |   0%
# liblapack-3.9.0      | 5.3 MB    | ###8       |  38%
# liblapack-3.9.0      | 5.3 MB    | ########## | 100%
# liblapack-3.9.0      | 5.3 MB    | ########## | 100%
#
# libopencv-4.5.5      | 47.5 MB   |            |   0%
# libopencv-4.5.5      | 47.5 MB   |            |   0%
# libopencv-4.5.5      | 47.5 MB   | 6          |   6%
# libopencv-4.5.5      | 47.5 MB   | #5         |  16%
# libopencv-4.5.5      | 47.5 MB   | ##3        |  23%
# libopencv-4.5.5      | 47.5 MB   | ###1       |  31%
# libopencv-4.5.5      | 47.5 MB   | ###9       |  40%
# libopencv-4.5.5      | 47.5 MB   | ####9      |  50%
# libopencv-4.5.5      | 47.5 MB   | #####8     |  58%
# libopencv-4.5.5      | 47.5 MB   | ######6    |  66%
# libopencv-4.5.5      | 47.5 MB   | #######5   |  76%
# libopencv-4.5.5      | 47.5 MB   | ########5  |  85%
# libopencv-4.5.5      | 47.5 MB   | #########4 |  94%
# libopencv-4.5.5      | 47.5 MB   | ########## | 100%
#
# py-opencv-4.5.5      | 25 KB     |            |   0%
# py-opencv-4.5.5      | 25 KB     | ########## | 100%
# py-opencv-4.5.5      | 25 KB     | ########## | 100%
#
# tbb-2021.5.0         | 148 KB    |            |   0%
# tbb-2021.5.0         | 148 KB    | ########## | 100%
# tbb-2021.5.0         | 148 KB    | ########## | 100%
#
# libtiff-4.3.0        | 1.1 MB    |            |   0%
# libtiff-4.3.0        | 1.1 MB    | ########## | 100%
# libtiff-4.3.0        | 1.1 MB    | ########## | 100%
#
# liblapacke-3.9.0     | 5.3 MB    |            |   0%
# liblapacke-3.9.0     | 5.3 MB    |            |   0%
# liblapacke-3.9.0     | 5.3 MB    | ###3       |  34%
# liblapacke-3.9.0     | 5.3 MB    | ########## | 100%
# liblapacke-3.9.0     | 5.3 MB    | ########## | 100%
#
# freeglut-3.2.2       | 150 KB    |            |   0%
# freeglut-3.2.2       | 150 KB    | #          |  11%
# freeglut-3.2.2       | 150 KB    | ########## | 100%
#
# opencv-4.5.5         | 23 KB     |            |   0%
# opencv-4.5.5         | 23 KB     | #######    |  70%
# opencv-4.5.5         | 23 KB     | ########## | 100%
#
# intel-openmp-2022.0. | 3.6 MB    |            |   0%
# intel-openmp-2022.0. | 3.6 MB    | ####7      |  47%
# intel-openmp-2022.0. | 3.6 MB    | ########## | 100%
# intel-openmp-2022.0. | 3.6 MB    | ########## | 100%
#
# mkl-2022.0.0         | 181.9 MB  |            |   0%
# mkl-2022.0.0         | 181.9 MB  |            |   1%
# mkl-2022.0.0         | 181.9 MB  | 3          |   3%
# mkl-2022.0.0         | 181.9 MB  | 5          |   5%
# mkl-2022.0.0         | 181.9 MB  | 7          |   8%
# mkl-2022.0.0         | 181.9 MB  | #          |  10%
# mkl-2022.0.0         | 181.9 MB  | #2         |  12%
# mkl-2022.0.0         | 181.9 MB  | #4         |  15%
# mkl-2022.0.0         | 181.9 MB  | #7         |  17%
# mkl-2022.0.0         | 181.9 MB  | #9         |  20%
# mkl-2022.0.0         | 181.9 MB  | ##1        |  22%
# mkl-2022.0.0         | 181.9 MB  | ##3        |  24%
# mkl-2022.0.0         | 181.9 MB  | ##5        |  26%
# mkl-2022.0.0         | 181.9 MB  | ##7        |  28%
# mkl-2022.0.0         | 181.9 MB  | ##9        |  30%
# mkl-2022.0.0         | 181.9 MB  | ###2       |  32%
# mkl-2022.0.0         | 181.9 MB  | ###4       |  34%
# mkl-2022.0.0         | 181.9 MB  | ###6       |  36%
# mkl-2022.0.0         | 181.9 MB  | ###8       |  38%
# mkl-2022.0.0         | 181.9 MB  | ####       |  40%
# mkl-2022.0.0         | 181.9 MB  | ####2      |  42%
# mkl-2022.0.0         | 181.9 MB  | ####4      |  44%
# mkl-2022.0.0         | 181.9 MB  | ####6      |  46%
# mkl-2022.0.0         | 181.9 MB  | ####8      |  49%
# mkl-2022.0.0         | 181.9 MB  | #####      |  51%
# mkl-2022.0.0         | 181.9 MB  | #####2     |  52%
# mkl-2022.0.0         | 181.9 MB  | #####3     |  54%
# mkl-2022.0.0         | 181.9 MB  | #####5     |  56%
# mkl-2022.0.0         | 181.9 MB  | #####7     |  58%
# mkl-2022.0.0         | 181.9 MB  | ######     |  60%
# mkl-2022.0.0         | 181.9 MB  | ######2    |  62%
# mkl-2022.0.0         | 181.9 MB  | ######4    |  65%
# mkl-2022.0.0         | 181.9 MB  | ######7    |  67%
# mkl-2022.0.0         | 181.9 MB  | ######9    |  70%
# mkl-2022.0.0         | 181.9 MB  | #######1   |  72%
# mkl-2022.0.0         | 181.9 MB  | #######4   |  74%
# mkl-2022.0.0         | 181.9 MB  | #######6   |  77%
# mkl-2022.0.0         | 181.9 MB  | #######8   |  79%
# mkl-2022.0.0         | 181.9 MB  | ########1  |  81%
# mkl-2022.0.0         | 181.9 MB  | ########3  |  83%
# mkl-2022.0.0         | 181.9 MB  | ########5  |  86%
# mkl-2022.0.0         | 181.9 MB  | ########7  |  88%
# mkl-2022.0.0         | 181.9 MB  | ########9  |  90%
# mkl-2022.0.0         | 181.9 MB  | #########1 |  92%
# mkl-2022.0.0         | 181.9 MB  | #########4 |  94%
# mkl-2022.0.0         | 181.9 MB  | #########6 |  97%
# mkl-2022.0.0         | 181.9 MB  | #########9 |  99%
# mkl-2022.0.0         | 181.9 MB  | ########## | 100%
#
# libdeflate-1.10      | 69 KB     |            |   0%
# libdeflate-1.10      | 69 KB     | ########## | 100%
#
# libcblas-3.9.0       | 5.3 MB    |            |   0%
# libcblas-3.9.0       | 5.3 MB    | ###3       |  33%
# libcblas-3.9.0       | 5.3 MB    | ########## | 100%
# libcblas-3.9.0       | 5.3 MB    | ########## | 100%
#
# numpy-1.21.5         | 5.6 MB    |            |   0%
# numpy-1.21.5         | 5.6 MB    |            |   0%
# numpy-1.21.5         | 5.6 MB    | ########2  |  82%
# numpy-1.21.5         | 5.6 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import random
import os
import cv2
#tesor fow & keras
import tensorflow as tf
from tensorflow import keras
from keras.regularizers import l2     
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import load_model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense,BatchNormalization,Dropout,Input
from keras.models import Sequential, Model
from keras.layers import Conv2D,GlobalMaxPooling2D
from tensorflow.keras.applications import  Xception,VGG16,InceptionResNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#cnn
from tensorflow.keras import datasets, layers, models

from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.engine.base_layer import Layer
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

# %%
seed = 42
np.random.seed =seed

# %%
import zipfile

with zipfile.ZipFile("C:/Users/crahu/Downloads/train.zip","r") as z:
    z.extractall(".")
    
with zipfile.ZipFile("C:/Users/crahu/Downloads/test1.zip","r") as z:
    z.extractall(".")

# %%
image_path = "C:/Users/crahu/Documents"

# %%
def get_Label(number):
    labels = {0:'Cat', 1:'Dog'}
    return labels[number]


#plot predction function
def plot_predection(model_name):
    plt.figure(figsize=(20,15))
    plt.suptitle("Predection  Images", fontsize=20)
    images = [] 
    path =image_path+'/'+'test1/'
    count = 0  #val_images,val_labels
    for i,files in enumerate(os.listdir(path)) :
        img = plt.imread(path+files)
        img = cv2.resize(img,(128,128))
        plt.imshow(img,cmap=plt.cm.binary)
        img = np.expand_dims(img, axis=0)
        feature = model_name.predict(img)
        predection  = np.argmax(feature, axis=1)
        plt.subplot(5,7,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.xlabel("Predicted"+get_Label(int(predection)))
        count += 1
        if count == 34 :
            break

# %%
all_categories = []
images = os.listdir("C:/Users/crahu/Documents/train")
for file in images:
    if file.split('.')[0] == 'dog':
        all_categories.append(1)
    else:
        all_categories.append(0)
#creat data fram to save each image with its label 
df =pd.DataFrame({
    'image': images,
    'category':all_categories
})

df.head(5)
# Out:
#           image  category
# 0     cat.0.jpg         0
# 1     cat.1.jpg         0
# 2    cat.10.jpg         0
# 3   cat.100.jpg         0
# 4  cat.1000.jpg         0

# %%
df['category'].value_counts()
# Out:
# 0    12500
# 1    12500
# Name: category, dtype: int64

# %%
plt.title('Train Labels Visualization')
sns.countplot(x=all_categories,palette='flare')
plt.show()

# %%
plt.figure(figsize=(20,15))
plt.suptitle("Train Images", fontsize=20)
path ="C:/Users/crahu/Documents/train/"
counter =0
for i,img in enumerate(os.listdir(path))  :
        plt.subplot(5,7,i+1)
        full_image= plt.imread(path+img)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.xlabel(get_Label(all_categories[i]))
        plt.imshow(full_image, cmap=plt.cm.binary) 
        if i == 34:
            break

# %%
df['category'] = df['category'].replace({1:'dog',0:'cat'})
df.head(10)
# Out:
#            image category
# 0      cat.0.jpg      cat
# 1      cat.1.jpg      cat
# 2     cat.10.jpg      cat
# 3    cat.100.jpg      cat
# 4   cat.1000.jpg      cat
# 5  cat.10000.jpg      cat
# 6  cat.10001.jpg      cat
# 7  cat.10002.jpg      cat
# 8  cat.10003.jpg      cat
# 9  cat.10004.jpg      cat

# %%
df['category'].value_counts()
# Out:
# cat    12500
# dog    12500
# Name: category, dtype: int64

# %%
x_train,x_val  = train_test_split(df ,random_state=42,shuffle=True,test_size=0.2)

# %%
x_train['category'].value_counts()
# Out:
# dog    10015
# cat     9985
# Name: category, dtype: int64

# %%
x_val['category'].value_counts()
# Out:
# cat    2515
# dog    2485
# Name: category, dtype: int64

# %%
x_train = x_train.reset_index(drop=True)
x_val = x_val.reset_index(drop=True)

# %%
print('Train Images shape is        : ',x_train.shape)
print('Validation  Images  shape is : ',x_val.shape)
# Out:
# Train Images shape is        :  (20000, 2)
# Validation  Images  shape is :  (5000, 2)

# %%
batch_size = 64
#create image generator for images 
image_gen = ImageDataGenerator(
                                 rescale = 1./255,
                                  shear_range = 0.2,
                                  zoom_range = 0.5,
                                  height_shift_range=0.2,
                                  width_shift_range=0.2,
                                  fill_mode='nearest',
                                   horizontal_flip=True,
                                   rotation_range = 20, 
                            
                               )

# Create Image Data Generator for Test/Validation Set
test_data_gen = ImageDataGenerator(  
                                   rescale = 1./255,
                                  shear_range = 0.2,
                                  zoom_range = 0.5,
                                  height_shift_range=0.2,
                                  width_shift_range=0.2,
                                  fill_mode='nearest',
                                   horizontal_flip=True,
                                   rotation_range = 20,)

        
train = image_gen.flow_from_dataframe(
      x_train,
      image_path+'/'+'train/',
      x_col='image',
      y_col='category',
      target_size=(128,128),
      class_mode='categorical',
      shuffle=True, 
      batch_size=batch_size
      )
validate = test_data_gen.flow_from_dataframe(
      x_val,
      image_path+'/'+'train/',
      x_col='image',
      y_col='category',
      target_size=(128,128),
      class_mode='categorical',
      shuffle=True, 
      batch_size=batch_size
      )
# Out:
# Found 20000 validated image filenames belonging to 2 classes.
# Found 5000 validated image filenames belonging to 2 classes.

# %%
for train_img , train_label in train :
    print('image shape ',train_img.shape)
    print('label  shape ',train_label.shape)
    break
# Out:
# image shape  (64, 128, 128, 3)
# label  shape  (64, 2)

# %%
for v_img , v_label in validate :
    print('image shape ',v_img.shape)
    print('label  shape ',v_label.shape)
    break
# Out:
# image shape  (64, 128, 128, 3)
# label  shape  (64, 2)

# %%
cnn_model = Sequential()
cnn_model = models.Sequential()
cnn_model.add(layers.Conv2D(64,(3,3),padding ='Same',activation = 'relu',input_shape=(128,128,3)))
cnn_model.add(layers.MaxPooling2D(2,2))
cnn_model.add(layers.Conv2D(64,(3,3) ,padding ='same',activation='relu'))
cnn_model.add(layers.MaxPooling2D(2,2))
cnn_model.add(layers.Conv2D(128,(3,3),padding ='same',activation='relu'))
cnn_model.add(layers.MaxPooling2D(2,2)) 
cnn_model.add(layers.Conv2D(128,(3,3) ,padding ='same',activation='relu'))
cnn_model.add(layers.MaxPooling2D(2,2)) 
cnn_model.add(layers.Conv2D(256,(3,3) ,padding ='same',activation='relu'))
cnn_model.add(layers.MaxPooling2D(2,2)) 
cnn_model.add(BatchNormalization())
cnn_model.add(layers.Conv2D(256,(3,3) ,padding ='same',activation='relu'))
cnn_model.add(layers.MaxPooling2D(2,2)) 
cnn_model.add(BatchNormalization())
cnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  batch_normalization (BatchN  (None, 4, 4, 256)        1024
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 256)         590080
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
# =================================================================
# Total params: 1,147,456
# Trainable params: 1,146,432
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
cnn_model.add(layers.Flatten())
cnn_model.add(layers.Dense(1024, activation='relu'))
cnn_model.add(BatchNormalization())
# cnn_model.add(Dropout(0.7))
cnn_model.add(layers.Dense(512, activation='relu'))
cnn_model.add(BatchNormalization())
# cnn_model.add(Dropout(0.3))
cnn_model.add(layers.Dense(2, activation ='softmax'))
cnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  batch_normalization (BatchN  (None, 4, 4, 256)        1024
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 256)         590080
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 1024)              1049600
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_2 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 2,729,026
# Trainable params: 2,724,930
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
cnn_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'],)

# %%
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
early = EarlyStopping(monitor="loss", mode="min",min_delta = 0,
                          patience = 10,
                          verbose = 1,
                          restore_best_weights = True)
learning_rate_reduction = ReduceLROnPlateau(monitor='loss', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
callbacks_list = [ early, learning_rate_reduction]

# %%
n_training_samples = len(train)
n_validation_samples = len(validate)
history = cnn_model.fit(
    train,
    epochs=60,
    validation_data=validate,
    validation_steps=n_validation_samples//batch_size,
    # steps_per_epoch =n_training_samples//batch_size,
    shuffle = True,
    callbacks=callbacks_list
    )
# Out:
# Epoch 1/60
# 313/313 [==============================] - 388s 1s/step - loss: 0.7511 - accuracy: 0.5440 - val_loss: 1.9500 - val_accuracy: 0.4844 - lr: 0.0010
# Epoch 2/60
# 313/313 [==============================] - 314s 1s/step - loss: 0.6695 - accuracy: 0.5995 - val_loss: 0.8631 - val_accuracy: 0.5938 - lr: 0.0010
# Epoch 3/60
# 313/313 [==============================] - 315s 1s/step - loss: 0.6389 - accuracy: 0.6337 - val_loss: 0.9204 - val_accuracy: 0.5312 - lr: 0.0010
# Epoch 4/60
# 313/313 [==============================] - 314s 1s/step - loss: 0.6135 - accuracy: 0.6673 - val_loss: 0.5847 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 5/60
# 313/313 [==============================] - 310s 991ms/step - loss: 0.5894 - accuracy: 0.6903 - val_loss: 0.6689 - val_accuracy: 0.6406 - lr: 0.0010
# Epoch 6/60
# 313/313 [==============================] - 313s 998ms/step - loss: 0.5817 - accuracy: 0.7003 - val_loss: 0.8409 - val_accuracy: 0.5312 - lr: 0.0010
# Epoch 7/60
# 313/313 [==============================] - 312s 995ms/step - loss: 0.5497 - accuracy: 0.7239 - val_loss: 0.5811 - val_accuracy: 0.7344 - lr: 0.0010
# Epoch 8/60
# 313/313 [==============================] - 313s 999ms/step - loss: 0.5234 - accuracy: 0.7408 - val_loss: 0.5091 - val_accuracy: 0.7344 - lr: 0.0010
# Epoch 9/60
# 313/313 [==============================] - 325s 1s/step - loss: 0.4971 - accuracy: 0.7606 - val_loss: 0.9904 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 10/60
# 313/313 [==============================] - 310s 990ms/step - loss: 0.4666 - accuracy: 0.7789 - val_loss: 0.5519 - val_accuracy: 0.7344 - lr: 0.0010
# Epoch 11/60
# 313/313 [==============================] - 324s 1s/step - loss: 0.4255 - accuracy: 0.8013 - val_loss: 0.5125 - val_accuracy: 0.7656 - lr: 0.0010
# Epoch 12/60
# 313/313 [==============================] - 323s 1s/step - loss: 0.3969 - accuracy: 0.8203 - val_loss: 0.2830 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 13/60
# 313/313 [==============================] - 323s 1s/step - loss: 0.3741 - accuracy: 0.8292 - val_loss: 0.3672 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 14/60
# 313/313 [==============================] - 326s 1s/step - loss: 0.3503 - accuracy: 0.8403 - val_loss: 0.3598 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 15/60
# 313/313 [==============================] - 317s 1s/step - loss: 0.3356 - accuracy: 0.8516 - val_loss: 0.3275 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 16/60
# 313/313 [==============================] - 320s 1s/step - loss: 0.3185 - accuracy: 0.8591 - val_loss: 0.3291 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 17/60
# 313/313 [==============================] - 336s 1s/step - loss: 0.3080 - accuracy: 0.8648 - val_loss: 0.2943 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 18/60
# 313/313 [==============================] - 345s 1s/step - loss: 0.2958 - accuracy: 0.8693 - val_loss: 0.3203 - val_accuracy: 0.8281 - lr: 0.0010
# Epoch 19/60
# 313/313 [==============================] - 347s 1s/step - loss: 0.2834 - accuracy: 0.8756 - val_loss: 0.1303 - val_accuracy: 0.9688 - lr: 0.0010
# Epoch 20/60
# 313/313 [==============================] - 345s 1s/step - loss: 0.2703 - accuracy: 0.8820 - val_loss: 0.2928 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 21/60
# 313/313 [==============================] - 342s 1s/step - loss: 0.2706 - accuracy: 0.8824 - val_loss: 0.2105 - val_accuracy: 0.9375 - lr: 0.0010
# Epoch 22/60
# 313/313 [==============================] - 330s 1s/step - loss: 0.2560 - accuracy: 0.8878 - val_loss: 0.2135 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 23/60
# 313/313 [==============================] - 348s 1s/step - loss: 0.2548 - accuracy: 0.8891 - val_loss: 0.2275 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 24/60
# 313/313 [==============================] - 352s 1s/step - loss: 0.2460 - accuracy: 0.8941 - val_loss: 0.3616 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 25/60
# 313/313 [==============================] - 336s 1s/step - loss: 0.2391 - accuracy: 0.8951 - val_loss: 0.1579 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 26/60
# 313/313 [==============================] - 336s 1s/step - loss: 0.2367 - accuracy: 0.8983 - val_loss: 0.3020 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 27/60
# 313/313 [==============================] - 353s 1s/step - loss: 0.2238 - accuracy: 0.9037 - val_loss: 0.1531 - val_accuracy: 0.9375 - lr: 0.0010
# Epoch 28/60
# 313/313 [==============================] - 362s 1s/step - loss: 0.2298 - accuracy: 0.9010 - val_loss: 0.4017 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 29/60
# 313/313 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9043
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 313/313 [==============================] - 364s 1s/step - loss: 0.2238 - accuracy: 0.9043 - val_loss: 0.2023 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 30/60
# 313/313 [==============================] - 358s 1s/step - loss: 0.1982 - accuracy: 0.9168 - val_loss: 0.2075 - val_accuracy: 0.9219 - lr: 3.0000e-04
# Epoch 31/60
# 313/313 [==============================] - 345s 1s/step - loss: 0.1909 - accuracy: 0.9187 - val_loss: 0.1348 - val_accuracy: 0.9844 - lr: 3.0000e-04
# Epoch 32/60
# 313/313 [==============================] - 340s 1s/step - loss: 0.1811 - accuracy: 0.9236 - val_loss: 0.0890 - val_accuracy: 0.9844 - lr: 3.0000e-04
# Epoch 33/60
# 313/313 [==============================] - 346s 1s/step - loss: 0.1768 - accuracy: 0.9273 - val_loss: 0.1614 - val_accuracy: 0.9219 - lr: 3.0000e-04
# Epoch 34/60
# 313/313 [==============================] - 344s 1s/step - loss: 0.1747 - accuracy: 0.9270 - val_loss: 0.2104 - val_accuracy: 0.9062 - lr: 3.0000e-04
# Epoch 35/60
# 313/313 [==============================] - 332s 1s/step - loss: 0.1695 - accuracy: 0.9278 - val_loss: 0.1883 - val_accuracy: 0.9062 - lr: 3.0000e-04
# Epoch 36/60
# 313/313 [==============================] - 319s 1s/step - loss: 0.1703 - accuracy: 0.9276 - val_loss: 0.2196 - val_accuracy: 0.8906 - lr: 3.0000e-04
# Epoch 37/60
# 313/313 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9313
# Epoch 37: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 313/313 [==============================] - 319s 1s/step - loss: 0.1704 - accuracy: 0.9313 - val_loss: 0.3646 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 38/60
# 313/313 [==============================] - 331s 1s/step - loss: 0.1570 - accuracy: 0.9338 - val_loss: 0.1584 - val_accuracy: 0.9062 - lr: 9.0000e-05
# Epoch 39/60
# 313/313 [==============================] - 349s 1s/step - loss: 0.1538 - accuracy: 0.9371 - val_loss: 0.1908 - val_accuracy: 0.9219 - lr: 9.0000e-05
# Epoch 40/60
# 313/313 [==============================] - 340s 1s/step - loss: 0.1537 - accuracy: 0.9366 - val_loss: 0.1747 - val_accuracy: 0.9375 - lr: 9.0000e-05
# Epoch 41/60
# 313/313 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9355
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 313/313 [==============================] - 337s 1s/step - loss: 0.1561 - accuracy: 0.9355 - val_loss: 0.1846 - val_accuracy: 0.9062 - lr: 9.0000e-05
# Epoch 42/60
# 313/313 [==============================] - 349s 1s/step - loss: 0.1476 - accuracy: 0.9395 - val_loss: 0.2296 - val_accuracy: 0.8906 - lr: 2.7000e-05
# Epoch 43/60
# 313/313 [==============================] - 346s 1s/step - loss: 0.1502 - accuracy: 0.9370 - val_loss: 0.1330 - val_accuracy: 0.9375 - lr: 2.7000e-05
# Epoch 44/60
# 313/313 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9407
# Epoch 44: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 313/313 [==============================] - 349s 1s/step - loss: 0.1483 - accuracy: 0.9407 - val_loss: 0.2068 - val_accuracy: 0.9062 - lr: 2.7000e-05
# Epoch 45/60
# 313/313 [==============================] - 348s 1s/step - loss: 0.1470 - accuracy: 0.9396 - val_loss: 0.2185 - val_accuracy: 0.9375 - lr: 8.1000e-06
# Epoch 46/60
# 313/313 [==============================] - 344s 1s/step - loss: 0.1472 - accuracy: 0.9395 - val_loss: 0.1454 - val_accuracy: 0.9062 - lr: 8.1000e-06
# Epoch 47/60
# 313/313 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9395
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 313/313 [==============================] - 344s 1s/step - loss: 0.1499 - accuracy: 0.9395 - val_loss: 0.2139 - val_accuracy: 0.9375 - lr: 8.1000e-06
# Epoch 48/60
# 313/313 [==============================] - 351s 1s/step - loss: 0.1450 - accuracy: 0.9405 - val_loss: 0.1229 - val_accuracy: 0.9531 - lr: 2.4300e-06
# Epoch 49/60
# 313/313 [==============================] - 341s 1s/step - loss: 0.1483 - accuracy: 0.9400 - val_loss: 0.1584 - val_accuracy: 0.9375 - lr: 2.4300e-06
# Epoch 50/60
# 313/313 [==============================] - 346s 1s/step - loss: 0.1436 - accuracy: 0.9413 - val_loss: 0.0904 - val_accuracy: 0.9688 - lr: 2.4300e-06
# Epoch 51/60
# 313/313 [==============================] - 354s 1s/step - loss: 0.1435 - accuracy: 0.9406 - val_loss: 0.0750 - val_accuracy: 0.9531 - lr: 2.4300e-06
# Epoch 52/60
# 313/313 [==============================] - 357s 1s/step - loss: 0.1423 - accuracy: 0.9432 - val_loss: 0.2229 - val_accuracy: 0.8750 - lr: 2.4300e-06
# Epoch 53/60
# 313/313 [==============================] - 353s 1s/step - loss: 0.1483 - accuracy: 0.9383 - val_loss: 0.0974 - val_accuracy: 0.9531 - lr: 2.4300e-06
# Epoch 54/60
# 313/313 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9413
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1e-06.
# 313/313 [==============================] - 352s 1s/step - loss: 0.1450 - accuracy: 0.9413 - val_loss: 0.1201 - val_accuracy: 0.9375 - lr: 2.4300e-06
# Epoch 55/60
# 313/313 [==============================] - 354s 1s/step - loss: 0.1447 - accuracy: 0.9409 - val_loss: 0.2326 - val_accuracy: 0.9062 - lr: 1.0000e-06
# Epoch 56/60
# 313/313 [==============================] - 359s 1s/step - loss: 0.1450 - accuracy: 0.9395 - val_loss: 0.1339 - val_accuracy: 0.9375 - lr: 1.0000e-06
# Epoch 57/60
# 313/313 [==============================] - 357s 1s/step - loss: 0.1456 - accuracy: 0.9384 - val_loss: 0.2791 - val_accuracy: 0.8906 - lr: 1.0000e-06
# Epoch 58/60
# 313/313 [==============================] - 356s 1s/step - loss: 0.1431 - accuracy: 0.9408 - val_loss: 0.1972 - val_accuracy: 0.9375 - lr: 1.0000e-06
# Epoch 59/60
# 313/313 [==============================] - 345s 1s/step - loss: 0.1471 - accuracy: 0.9388 - val_loss: 0.1785 - val_accuracy: 0.9062 - lr: 1.0000e-06
# Epoch 60/60
# 313/313 [==============================] - 338s 1s/step - loss: 0.1438 - accuracy: 0.9417 - val_loss: 0.2302 - val_accuracy: 0.8906 - lr: 1.0000e-06

# %%
cnn_prediction = cnn_model.predict(validate)
cnn_prediction
# Out:
# array([[9.9952102e-01, 4.7901203e-04],
#        [9.9933702e-01, 6.6294568e-04],
#        [9.9877030e-01, 1.2297262e-03],
#        ...,
#        [9.8493052e-01, 1.5069472e-02],
#        [9.9999726e-01, 2.7240012e-06],
#        [7.8271186e-01, 2.1728808e-01]], dtype=float32)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()
